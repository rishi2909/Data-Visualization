# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#seaborn: statistical data visulaization
sns.get_dataset_names() # these are the datasets that are provided by seaborn.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#numerical data plotting >> how to plot some numerical data , by default seaborn.replot has scatter plot.
sns.relplot(x=df.total_bill, y=df.tip, data=df) #use to understand relationship b/w two variables. it is similar to scatter plot.

# %%
sns.scatterplot(x='total_bill',y='tip',data=df) #
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# we want to know that which one was smokers
sns.scatterplot(x=df.total_bill, y=df.tip, data=df,hue = 'smoker') # The hue parameter in sns.scatterplot() is used to color the points based on a categorical variable. This helps in visually distinguishing different groups within the data.
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#insights
# as the bill inc, the tip also inc
#highest tip was paid by a smoker
sns.relplot(x='total_bill',y='tip',data=df,hue='smoker')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=df,style='time',hue='smoker') # style Changes marker shape/line style based on a category

# %%
sns.relplot(x='total_bill',y='tip',data=df,style='smoker',hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df,style='size')

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()
df = pd.DataFrame({'time':time,'value':value})
df
# Out:
#      time     value
# 0       0 -0.655153
# 1       1 -0.583976
# 2       2 -0.912834
# 3       3 -3.221680
# 4       4 -2.076397
# ..    ...       ...
# 495   495  0.833311
# 496   496  1.595060
# 497   497  3.542325
# 498   498  3.159805
# 499   499  2.995819
#
# [500 rows x 2 columns]

# %%
value
# Out:
# array([-0.65515293, -0.58397632, -0.91283392, -3.22167981, -2.07639738,
#        -2.30177506, -3.33834484, -4.26616279, -5.26695727, -5.67725255,
#        -3.68955958, -4.14525445, -3.3724984 , -3.24089042, -4.08825046,
#        -2.56020951, -2.623407  , -2.19415844, -2.70160999, -2.84998334,
#        -3.53357884, -3.17051688, -2.48889461, -1.82259538, -3.16169198,
#        -2.08685929, -3.12710527, -3.61875025, -3.80347619, -3.21114182,
#        -2.10277398, -1.84632725, -2.88684502, -2.80415792, -2.90290455,
#        -2.21213851, -2.38912575, -0.88018539,  0.25302499,  0.41581396,
#         0.99422102,  1.74009558,  3.40146198,  3.41971183,  3.33748008,
#         3.4059813 ,  3.82519633,  3.62070467,  5.03311601,  5.66092531,
#         6.00419012,  7.97455166,  9.14838334, 10.61947941, 11.00465204,
#        11.43116255, 11.69234508, 11.94253607, 10.95676427, 11.158832  ,
#        11.38859485, 10.86365613, 10.68602885, 10.60828519, 11.35854933,
# ...

# %%
sns.relplot(x='time',y='value', kind = 'line',data=df,sort=True)

# %%
df1 = sns.load_dataset('fmri')
df1
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x=df1.timepoint,y=df1.signal,kind='line')  #the shadow here represent confidence interval

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
sns.relplot(x=df1.timepoint,y=df1.signal,kind='line',ci='sd')  #the shadow reprsent standard deviation.
# Out:
# C:\Users\Rishi Raj\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
# if i do not want confidence interval then
sns.relplot(x=df1.timepoint,y=df1.signal,estimator=None,kind='line',errorbar='sd')

# %%
sns.relplot(x='timepoint',y='signal',data=df1,kind='line',hue='event')

# %%
df1
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint',y='signal',data=df1,kind='line',hue='event',style='region')

# %%
sns.relplot(x='timepoint',y='signal',data=df1,kind='line',hue='event',style='region',marker=False,dashes=True)

# %%
sns.relplot(x='timepoint',y='signal',data=df1,kind='line',hue='event',style='region',marker=True,dashes=False)

# %%
#if you want to see the things in differenrt group
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=df,col='time')

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=df,col='sex')

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=df,col='size')

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=df,col='day')

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='day',y='total_bill',data=df)

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.catplot(x='day',y='total_bill',data=df,kind='box')
#
# NameError: name 'df' is not defined

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='swarm')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='boxen')

# %%
sns.barplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=df.total_bill, y=df.tip) #raw a plot of two variables with bivariate and univariate graphs.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x=df.total_bill, y=df.tip, kind='hex')

# %%
sns.jointplot(x=df.total_bill, y=df.tip, kind='kde')  #kernal density estimation. it is also known as contout plot by meterological department.

# %%
sns.jointplot(x=df.total_bill, y=df.tip, kind='reg')  #

# %%
#pairplot >> it will plot all the pair wise relationship b/w datatframes
sns.pairplot(df)

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='smoker',palette='coolwarm')

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow')
# Out:
# C:\Users\Rishi Raj\AppData\Local\Temp\ipykernel_9488\3515153989.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
#how to see correlation relationship b/w diff variables.
df5 = df[['total_bill','tip','size']]

# %%
df5.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df5.corr(),cmap = 'coolwarm',annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to make countplot
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y='tip',data=df)

# %%
#to change the height.
sns.lmplot(x='total_bill', y='tip',data=df,height=15)

# %%
#if you want to zoom in and zoom out we have assign in aspect the value = 1
sns.lmplot(x='total_bill', y='tip',data=df,height=15,aspect=1)
